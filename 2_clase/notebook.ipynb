# %% [markdown]
# # Dato tipo int y float en Python (operaciones)

# %%
12, type(12)
# Out:
# (12, int)

# %%
12.1, type(12.1)
# Out:
# (12.1, float)

# %%
12 + 12.1
# Out:
# 24.1

# %%
24 - 12
# Out:
# 12

# %%
12/2
# Out:
# 6.0

# %%
12//2, 13//2
# Out:
# (6, 6)

# %%
12 * 2
# Out:
# 24

# %%
2 % 13
# Out:
# 2

# %%
13 % 2
# Out:
# 1

# %%
4 % 2
# Out:
# 0

# %%
3 ** 2
# Out:
# 9

# %%
3 ** (2 ** 2)
# Out:
# 81

# %%
2 ** (1/2)
# Out:
# 1.4142135623730951

# %% [markdown]
# # String en python (operaciones)

# %%
"hola"
# Out:
# 'hola'

# %%
"hola " + "mundo"
# Out:
# 'hola mundo'

# %%
"a" * 10
# Out:
# 'aaaaaaaaaa'

# %%
"a" + "a"
# Out:
# 'aa'

# %% [markdown]
# # Booleano en python (operaciones)

# %%
True, False
# Out:
# (True, False)

# %% [markdown]
# ## And, Or, Not

# %%
True and False, True and True, False and True, False and False
# Out:
# (False, True, False, False)

# %%
True or False, True or True, False or True, False or False
# Out:
# (True, True, True, False)

# %%
not True, not False
# Out:
# (False, True)

# %%
(True and True) or False
# Out:
# True

# %% [markdown]
# # Extra

# %%
0xFF, 0o77, 0b1000
# Out:
# (255, 63, 8)

# %%
2 >> 1, 2 << 1
# Out:
# (1, 4)

# %% [markdown]
# # Variables en python (asignan y usan)

# %%
ema = "Emanuel"
type(ema)
# Out:
# str

# %%
var1 = 10
var2 = 5.5

# %%
snake_case = 10
PascalCase = 20
camelCase = 30
snakecase = 40

# %%
peso_cohete = 1000 # IN KG

# %%
class RocketShip:
    pass

# %% [markdown]
# # Ejercicio

# %%
num1 = 10
num2 = 5.5

res_suma = num1 + num2
res_resta = num1 - num2
res_multi = num1 * num2
res_div = num1 / num2

print("Suma", res_suma)
print("Resta", res_resta)
print("Multi", res_multi)
print("Div", res_div)
# Out:
# Suma 15.5
# Resta 4.5
# Multi 55.0
# Div 1.8181818181818181
