# %% [markdown]
# # Manejo de Strings

# %%
string_1 = "Hola como estás"

# %%
string_1[3]
# Out:
# 'a'

# %%
string_1[1:4], string_1[4:], string_1[:4], string_1[1::2]
# Out:
# ('ola', ' como estás', 'Hola', 'oacm sá')

# %%
string_1[::-1], string_1[-1::-1]
# Out:
# ('sátse omoc aloH', 'sátse omoc aloH')

# %%
string_1[0] = "l"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 string_1[0] = "l"
#
# TypeError: 'str' object does not support item assignment

# %%
string_1
# Out:
# 'Hola como estás'

# %%
string_2 = string_1.replace(" ", "")
string_2
# Out:
# 'Holacomoestás'

# %%
lista_1 = string_1.split(" ")
lista_1
# Out:
# ['Hola', 'como', 'estás']

# %%
" ".join(lista_1)
# Out:
# 'Hola como estás'

# %% [markdown]
# # Listas

# %%
lista_1
# Out:
# ['Hola', 'como', 'estás']

# %%
lista_1[0], lista_1[0][0]
# Out:
# ('Hola', 'H')

# %%
lista_1[:-1]
# Out:
# ['Hola', 'como']

# %%
lista_1.append("Emanuel")

# %%
lista_1
# Out:
# ['Hola', 'como', 'estás', 'Emanuel']

# %%
len(lista_1), len(lista_1[0])
# Out:
# (4, 4)

# %%
lista_1[0] = "Chao"
lista_1
# Out:
# ['Chao', 'como', 'estás', 'Emanuel']

# %%
lista_1.pop()
# Out:
# 'Emanuel'

# %%
lista_1
# Out:
# ['Chao', 'como', 'estás']

# %%
lista_1.reverse()

# %%
lista_1
# Out:
# ['estás', 'como', 'Chao']

# %%
lista_1.append(10)

# %%
lista_1
# Out:
# ['estás', 'como', 'Chao', 10]

# %%
lista_1.append(["chao", 1.0])

# %%
lista_1
# Out:
# ['estás', 'como', 'Chao', 10, ['chao', 1.0]]

# %%
lista_1.append((1, 2, 3))

# %%
lista_1
# Out:
# ['estás', 'como', 'Chao', 10, ['chao', 1.0], (1, 2, 3)]
