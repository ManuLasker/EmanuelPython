# %%
def calcular_perimetro_rectangulo(largo, ancho):
    perimetro = 2 * largo + 2 * ancho
    return perimetro

# %%
p = calcular_perimetro_rectangulo(5, 3)

print("El perimetro es de : ", p)
# Out:
# El perimetro es de :  16

# %%
def prueba_sin_retorno(va1):
    print(va1)

# %%
res = prueba_sin_retorno("Hola")

print("Que será res: ", res)
# Out:
# Hola
# Que será res:  None

# %%
nombre1  = "Emanuel"
nombre2 = "Manuel"

nombre1 == nombre2
# Out:
# False

# %%
nombre1  = "Emanuel"
nombre2 = "Emanuel"

nombre1 == nombre2
# Out:
# True

# %%
num1 = 4
num2 = 2

num1 < num2, num1 > num2, num1 == num2, num1 != num2
# Out:
# (False, True, False, True)

# %%
num1 <= num2, num1 >= num2
# Out:
# (False, True)

# %%
comp1 = (num1 > num2) and (nombre1 == nombre2)
print(comp1)
# Out:
# True

# %%
def positive(num):
    return num > 0

# %%
positive(3)
# Out:
# True
