# %%
print("hola mundo")
# Out:
# hola mundo

# %%
numero = input("Hey intruce un numero")

# %%
type(numero)
# Out:
# str

# %%
numero = float(numero)
numero
# Out:
# 10.0

# %%
numero = int(numero)
numero
# Out:
# 10

# %%
float("10.5")
# Out:
# 10.5
